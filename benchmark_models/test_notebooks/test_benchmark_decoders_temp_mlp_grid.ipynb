# %%
import os
import sys

sys.path.append(os.path.join(".."))
import benchmark_decoders

sys.path.append(os.path.join("../.."))
import visualization
# Out:
# /home/SRastegarnia/.virtualenvs/benchmark_env/lib/python3.6/site-packages/nilearn/__init__.py:69: FutureWarning: Python 3.6 support is deprecated and will be removed in release 0.10 of Nilearn. Consider switching to Python 3.8 or 3.9.
#   _python_deprecation_warnings()
# /home/SRastegarnia/.virtualenvs/benchmark_env/lib/python3.6/site-packages/nilearn/input_data/__init__.py:27: FutureWarning: The import path 'nilearn.input_data' is deprecated in version 0.9. Importing from 'nilearn.input_data' will be possible at least until release 0.13.0. Please import from 'nilearn.maskers' instead.
#   warnings.warn(message, FutureWarning)

# %%
subject = 'sub-01' # ['sub-01','sub-02','sub-03','sub-04','sub-05','sub-06']
modalities = ['emotion','language','motor','relational','social','wm']
decoders = ['grid_mlp'] #,'mlp','knn','random_forest','grid_mlp','grid_svm' 
HRFlag_process = '3volumes' # ['3volumes','2-1volumes','without']

# %%
region_approach = 'dypac' # ['MIST','difumo','dypac','volume']
resolution = 256

benchmark_decoders.postproc_benchmark_decoder(subject, modalities, decoders,
                                              region_approach, HRFlag_process, resolution)
# Out:
# ('sub-01', 'dypac', 256, '3volumes')
# ------------------------------------------------------------------------------------------------
# ['/home/SRastegarnia/hcptrt_decoding_Shima/data/processed_data/proc_fMRI/dypac/256/sub-01/sub-01_emotion_3volumes_final_fMRI.npy']
# ['/home/SRastegarnia/hcptrt_decoding_Shima/data/processed_data/proc_fMRI/dypac/256/sub-01/sub-01_language_3volumes_final_fMRI.npy']
# ['/home/SRastegarnia/hcptrt_decoding_Shima/data/processed_data/proc_fMRI/dypac/256/sub-01/sub-01_motor_3volumes_final_fMRI.npy']
# ['/home/SRastegarnia/hcptrt_decoding_Shima/data/processed_data/proc_fMRI/dypac/256/sub-01/sub-01_relational_3volumes_final_fMRI.npy']
# ['/home/SRastegarnia/hcptrt_decoding_Shima/data/processed_data/proc_fMRI/dypac/256/sub-01/sub-01_social_3volumes_final_fMRI.npy']
# ['/home/SRastegarnia/hcptrt_decoding_Shima/data/processed_data/proc_fMRI/dypac/256/sub-01/sub-01_wm_3volumes_final_fMRI.npy']
# Generating concatenated bold and labels files is done, for sub-01 with 3volumes HRFlag method,
#  and dypac 256 parcelation approach.
#
# all_modality_concat_bold shape (8101, 256)
# all_modality_concat_labels shape (8101,)
#
# Multi Layer Perceptron Neural Networks classifier with grid search
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# Best parameters found:
#  {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.159 (+/-0.018) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.307 (+/-0.035) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.159 (+/-0.018) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.307 (+/-0.035) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.192 (+/-0.020) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (128, 64), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.317 (+/-0.029) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (128, 64), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.192 (+/-0.020) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (128, 64), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.317 (+/-0.029) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (128, 64), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.165 (+/-0.024) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': 128, 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.289 (+/-0.017) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': 128, 'learning_rate': 'constant', 'solver': 'adam'}
# 0.165 (+/-0.024) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': 128, 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.289 (+/-0.017) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': 128, 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.158 (+/-0.017) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.323 (+/-0.024) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.158 (+/-0.017) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.323 (+/-0.024) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.191 (+/-0.021) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (128, 64), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.332 (+/-0.022) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (128, 64), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.191 (+/-0.021) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (128, 64), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.332 (+/-0.022) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (128, 64), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.164 (+/-0.024) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': 128, 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.302 (+/-0.023) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': 128, 'learning_rate': 'constant', 'solver': 'adam'}
# 0.164 (+/-0.024) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': 128, 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.302 (+/-0.023) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': 128, 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.300 (+/-0.028) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.360 (+/-0.025) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.300 (+/-0.028) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.360 (+/-0.025) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.290 (+/-0.023) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (128, 64), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.383 (+/-0.017) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (128, 64), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.290 (+/-0.023) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (128, 64), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.383 (+/-0.017) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (128, 64), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.253 (+/-0.015) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': 128, 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.389 (+/-0.031) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': 128, 'learning_rate': 'constant', 'solver': 'adam'}
# 0.253 (+/-0.015) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': 128, 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.389 (+/-0.031) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': 128, 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.298 (+/-0.033) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.400 (+/-0.014) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.298 (+/-0.033) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.400 (+/-0.014) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.290 (+/-0.020) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (128, 64), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.390 (+/-0.027) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (128, 64), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.290 (+/-0.020) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (128, 64), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.390 (+/-0.027) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (128, 64), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.252 (+/-0.015) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': 128, 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.391 (+/-0.030) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': 128, 'learning_rate': 'constant', 'solver': 'adam'}
# 0.252 (+/-0.015) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': 128, 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.391 (+/-0.030) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': 128, 'learning_rate': 'adaptive', 'solver': 'adam'}
# Best model estimation after hyper-parameter tuning:
#  MLPClassifier(alpha=0.05, hidden_layer_sizes=(128, 64, 32), random_state=0)
# Results on the test set:
#               precision    recall  f1-score   support
#
#            0       0.40      0.25      0.31        56
#            1       0.67      0.34      0.45        58
#            2       0.64      0.47      0.54        68
#            3       0.66      0.48      0.55        65
#            4       0.71      0.53      0.61        57
#            5       0.65      0.44      0.53        34
#            6       0.48      0.31      0.38        35
#            7       0.62      0.45      0.53        22
#            8       0.71      0.56      0.63        27
#            9       0.64      0.43      0.51       110
#           10       0.81      0.68      0.73       197
#           11       0.63      0.57      0.60       161
#           12       0.40      0.25      0.31        48
#           13       0.40      0.33      0.36        49
#           14       0.58      0.47      0.52       159
#           15       0.61      0.48      0.54        79
#           16       0.68      0.46      0.55        82
#           17       0.73      0.65      0.69       179
#           18       0.57      0.52      0.54        25
#           19       0.50      0.29      0.36        49
#           20       0.39      0.20      0.26        61
#
#    micro avg       0.64      0.48      0.55      1621
#    macro avg       0.59      0.44      0.50      1621
# weighted avg       0.63      0.48      0.54      1621
#  samples avg       0.45      0.48      0.46      1621
# /home/SRastegarnia/.virtualenvs/benchmark_env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
region_approach = 'MIST'
resolution = 444

benchmark_decoders.postproc_benchmark_decoder(subject, modalities, decoders,
                                              region_approach, HRFlag_process, resolution)
# Out:
# ('sub-01', 'MIST', 444, '3volumes')
# ------------------------------------------------------------------------------------------------
# ['/home/SRastegarnia/hcptrt_decoding_Shima/data/processed_data/proc_fMRI/MIST/444/sub-01/sub-01_emotion_3volumes_final_fMRI.npy']
# ['/home/SRastegarnia/hcptrt_decoding_Shima/data/processed_data/proc_fMRI/MIST/444/sub-01/sub-01_language_3volumes_final_fMRI.npy']
# ['/home/SRastegarnia/hcptrt_decoding_Shima/data/processed_data/proc_fMRI/MIST/444/sub-01/sub-01_motor_3volumes_final_fMRI.npy']
# ['/home/SRastegarnia/hcptrt_decoding_Shima/data/processed_data/proc_fMRI/MIST/444/sub-01/sub-01_relational_3volumes_final_fMRI.npy']
# ['/home/SRastegarnia/hcptrt_decoding_Shima/data/processed_data/proc_fMRI/MIST/444/sub-01/sub-01_social_3volumes_final_fMRI.npy']
# ['/home/SRastegarnia/hcptrt_decoding_Shima/data/processed_data/proc_fMRI/MIST/444/sub-01/sub-01_wm_3volumes_final_fMRI.npy']
# Generating concatenated bold and labels files is done, for sub-01 with 3volumes HRFlag method,
#  and MIST 444 parcelation approach.
#
# all_modality_concat_bold shape (8101, 444)
# all_modality_concat_labels shape (8101,)
#
# Multi Layer Perceptron Neural Networks classifier with grid search
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# Best parameters found:
#  {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (222, 111), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.346 (+/-0.017) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (222, 111, 55), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.396 (+/-0.066) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (222, 111, 55), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.346 (+/-0.017) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (222, 111, 55), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.396 (+/-0.066) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (222, 111, 55), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.361 (+/-0.029) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (222, 111), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.409 (+/-0.041) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (222, 111), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.361 (+/-0.029) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (222, 111), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.409 (+/-0.041) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (222, 111), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.319 (+/-0.031) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': 222, 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.362 (+/-0.035) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': 222, 'learning_rate': 'constant', 'solver': 'adam'}
# 0.319 (+/-0.031) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': 222, 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.362 (+/-0.035) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': 222, 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.346 (+/-0.021) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (222, 111, 55), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.460 (+/-0.033) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (222, 111, 55), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.346 (+/-0.021) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (222, 111, 55), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.460 (+/-0.033) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (222, 111, 55), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.362 (+/-0.029) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (222, 111), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.455 (+/-0.032) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (222, 111), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.362 (+/-0.029) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (222, 111), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.455 (+/-0.032) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (222, 111), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.320 (+/-0.033) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': 222, 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.390 (+/-0.037) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': 222, 'learning_rate': 'constant', 'solver': 'adam'}
# 0.320 (+/-0.033) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': 222, 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.390 (+/-0.037) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': 222, 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.451 (+/-0.016) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (222, 111, 55), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.501 (+/-0.038) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (222, 111, 55), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.451 (+/-0.016) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (222, 111, 55), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.501 (+/-0.038) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (222, 111, 55), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.479 (+/-0.018) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (222, 111), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.527 (+/-0.025) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (222, 111), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.479 (+/-0.018) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (222, 111), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.527 (+/-0.025) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (222, 111), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.461 (+/-0.025) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': 222, 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.523 (+/-0.022) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': 222, 'learning_rate': 'constant', 'solver': 'adam'}
# 0.461 (+/-0.025) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': 222, 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.523 (+/-0.022) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': 222, 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.453 (+/-0.017) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (222, 111, 55), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.563 (+/-0.042) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (222, 111, 55), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.453 (+/-0.017) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (222, 111, 55), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.563 (+/-0.042) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (222, 111, 55), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.480 (+/-0.020) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (222, 111), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.566 (+/-0.031) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (222, 111), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.480 (+/-0.020) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (222, 111), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.566 (+/-0.031) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (222, 111), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.461 (+/-0.023) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': 222, 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.533 (+/-0.034) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': 222, 'learning_rate': 'constant', 'solver': 'adam'}
# 0.461 (+/-0.023) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': 222, 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.533 (+/-0.034) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': 222, 'learning_rate': 'adaptive', 'solver': 'adam'}
# Best model estimation after hyper-parameter tuning:
#  MLPClassifier(alpha=0.05, hidden_layer_sizes=(222, 111), random_state=0)
# Results on the test set:
#               precision    recall  f1-score   support
#
#            0       0.76      0.61      0.67        56
#            1       0.87      0.69      0.77        58
#            2       0.85      0.50      0.63        68
#            3       0.84      0.75      0.80        65
#            4       0.96      0.75      0.84        57
#            5       1.00      0.76      0.87        34
#            6       0.88      0.60      0.71        35
#            7       0.89      0.77      0.83        22
#            8       0.91      0.74      0.82        27
#            9       0.79      0.52      0.63       110
#           10       0.88      0.80      0.84       197
#           11       0.81      0.71      0.76       161
#           12       0.74      0.48      0.58        48
#           13       0.69      0.49      0.57        49
#           14       0.81      0.60      0.69       159
#           15       0.82      0.62      0.71        79
#           16       0.92      0.74      0.82        82
#           17       0.92      0.75      0.83       179
#           18       1.00      0.84      0.91        25
#           19       0.74      0.47      0.58        49
#           20       0.76      0.41      0.53        61
#
#    micro avg       0.85      0.66      0.74      1621
#    macro avg       0.85      0.65      0.73      1621
# weighted avg       0.85      0.66      0.74      1621
#  samples avg       0.64      0.66      0.64      1621
# /home/SRastegarnia/.virtualenvs/benchmark_env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
